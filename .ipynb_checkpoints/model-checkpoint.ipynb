# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# ## Set of constants

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS=30
EPOCHS=30
data_dir = "FIDS302"

# %% [markdown]
# ## Importing the Dataset

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 971 files belonging to 30 classes.

# %%
class_names = dataset.class_names
print(len(class_names))
class_names
# Out:
# 30
# ['acerolas',
#  'apples',
#  'apricots',
#  'avocados',
#  'bananas',
#  'blackberries',
#  'blueberries',
#  'cantaloupes',
#  'cherries',
#  'coconuts',
#  'figs',
#  'grapefruits',
#  'grapes',
#  'guava',
#  'kiwifruit',
#  'lemons',
#  'limes',
#  'mangos',
#  'olives',
#  'oranges',
#  'passionfruit',
#  'peaches',
#  'pears',
#  'pineapples',
#  'plums',
#  'pomegranates',
#  'raspberries',
#  'strawberries',
#  'tomatoes',
#  'watermelons']

# %% [markdown]
# ## Preprocess the Dataset

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 256, 256, 3)
# [ 5 11 27 21 24 19  3 22  6 14 11 19 17 24 11 21 22 12 21 17  4 22  5 25
#   1  8 25  6  4 21 23 18]

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# #### Splitting the dataset

# %%
len(dataset)
# Out:
# 31

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 24.8

# %%
train_ds = dataset.take(24)
len(train_ds)
# Out:
# 24

# %%
test_ds = dataset.skip(24)
len(test_ds)
# Out:
# 7

# %%
val_size=0.1
len(dataset)*val_size
# Out:
# 3.1

# %%
val_ds = test_ds.take(3)
len(val_ds)
# Out:
# 3

# %%
test_ds = test_ds.skip(3)
len(test_ds)
# Out:
# 4

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 24

# %%
len(val_ds)
# Out:
# 3

# %%
len(test_ds)
# Out:
# 4

# %% [markdown]
# ## Cache, Shuffle, and Prefetch the Dataset

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## Building the Model

# %% [markdown]
# ### Creating a Layer for Resizing and Normalization

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %% [markdown]
# ### Data Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
])

# %% [markdown]
# ### Applying Data Augmentation to Train Dataset

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# ### Model Architecture

# %%
num_classes = 30

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=EPOCHS
)
# Out:
# Epoch 1/30
# 24/24 [==============================] - 92s 4s/step - loss: 2.0958 - accuracy: 0.3464 - val_loss: 2.1580 - val_accuracy: 0.3229
# Epoch 2/30
# 24/24 [==============================] - 91s 4s/step - loss: 2.0006 - accuracy: 0.3711 - val_loss: 1.9882 - val_accuracy: 0.3958
# Epoch 3/30
# 24/24 [==============================] - 90s 4s/step - loss: 1.7015 - accuracy: 0.4531 - val_loss: 1.5522 - val_accuracy: 0.4896
# Epoch 4/30
# 24/24 [==============================] - 93s 4s/step - loss: 1.5565 - accuracy: 0.4753 - val_loss: 1.4923 - val_accuracy: 0.5833
# Epoch 5/30
# 24/24 [==============================] - 91s 4s/step - loss: 1.4195 - accuracy: 0.5339 - val_loss: 1.3287 - val_accuracy: 0.6042
# Epoch 6/30
# 24/24 [==============================] - 102s 4s/step - loss: 1.2778 - accuracy: 0.5534 - val_loss: 1.3677 - val_accuracy: 0.5729
# Epoch 7/30
# 24/24 [==============================] - 108s 5s/step - loss: 1.1729 - accuracy: 0.6289 - val_loss: 1.3147 - val_accuracy: 0.5938
# Epoch 8/30
# 24/24 [==============================] - 91s 4s/step - loss: 1.1561 - accuracy: 0.6120 - val_loss: 1.2806 - val_accuracy: 0.5521
# Epoch 9/30
# 24/24 [==============================] - 90s 4s/step - loss: 1.0645 - accuracy: 0.6719 - val_loss: 1.0713 - val_accuracy: 0.6354
# Epoch 10/30
# 24/24 [==============================] - 91s 4s/step - loss: 1.0545 - accuracy: 0.6576 - val_loss: 1.3345 - val_accuracy: 0.5938
# Epoch 11/30
# 24/24 [==============================] - 94s 4s/step - loss: 0.9414 - accuracy: 0.7057 - val_loss: 1.2219 - val_accuracy: 0.6146
# Epoch 12/30
# 24/24 [==============================] - 91s 4s/step - loss: 0.8621 - accuracy: 0.7057 - val_loss: 0.8304 - val_accuracy: 0.7396
# Epoch 13/30
# 24/24 [==============================] - 90s 4s/step - loss: 0.8005 - accuracy: 0.7396 - val_loss: 1.0777 - val_accuracy: 0.7188
# Epoch 14/30
# 24/24 [==============================] - 93s 4s/step - loss: 0.7582 - accuracy: 0.7396 - val_loss: 0.9412 - val_accuracy: 0.7396
# Epoch 15/30
# 24/24 [==============================] - 91s 4s/step - loss: 0.6091 - accuracy: 0.8021 - val_loss: 0.9624 - val_accuracy: 0.7396
# Epoch 16/30
# 24/24 [==============================] - 93s 4s/step - loss: 0.6408 - accuracy: 0.7891 - val_loss: 0.9485 - val_accuracy: 0.6771
# Epoch 17/30
# 24/24 [==============================] - 90s 4s/step - loss: 0.7064 - accuracy: 0.7656 - val_loss: 0.8169 - val_accuracy: 0.7812
# Epoch 18/30
# 24/24 [==============================] - 91s 4s/step - loss: 0.5148 - accuracy: 0.8255 - val_loss: 0.9114 - val_accuracy: 0.7500
# Epoch 19/30
# 24/24 [==============================] - 92s 4s/step - loss: 0.5700 - accuracy: 0.7995 - val_loss: 1.1107 - val_accuracy: 0.6771
# Epoch 20/30
# 24/24 [==============================] - 93s 4s/step - loss: 0.4810 - accuracy: 0.8503 - val_loss: 0.9235 - val_accuracy: 0.7292
# Epoch 21/30
# 24/24 [==============================] - 92s 4s/step - loss: 0.4768 - accuracy: 0.8451 - val_loss: 0.8555 - val_accuracy: 0.7812
# Epoch 22/30
# 24/24 [==============================] - 90s 4s/step - loss: 0.4204 - accuracy: 0.8529 - val_loss: 0.6939 - val_accuracy: 0.8021
# Epoch 23/30
# 24/24 [==============================] - 93s 4s/step - loss: 0.4381 - accuracy: 0.8529 - val_loss: 0.8912 - val_accuracy: 0.7604
# Epoch 24/30
# 24/24 [==============================] - 93s 4s/step - loss: 0.4029 - accuracy: 0.8737 - val_loss: 0.7123 - val_accuracy: 0.8438
# Epoch 25/30
# 24/24 [==============================] - 89s 4s/step - loss: 0.3185 - accuracy: 0.9076 - val_loss: 0.9046 - val_accuracy: 0.8125
# Epoch 26/30
# 24/24 [==============================] - 90s 4s/step - loss: 0.3781 - accuracy: 0.8685 - val_loss: 0.8098 - val_accuracy: 0.8021
# Epoch 27/30
# 24/24 [==============================] - 91s 4s/step - loss: 0.4914 - accuracy: 0.8490 - val_loss: 0.6519 - val_accuracy: 0.8333
# Epoch 28/30
# 24/24 [==============================] - 89s 4s/step - loss: 0.3783 - accuracy: 0.8737 - val_loss: 0.6163 - val_accuracy: 0.8438
# Epoch 29/30
# 24/24 [==============================] - 91s 4s/step - loss: 0.3665 - accuracy: 0.8789 - val_loss: 0.6697 - val_accuracy: 0.8438
# Epoch 30/30
# 24/24 [==============================] - 90s 4s/step - loss: 0.3107 - accuracy: 0.9062 - val_loss: 0.6669 - val_accuracy: 0.8125

# %%
scores = model.evaluate(test_ds)
# Out:
# 2023-04-02 04:41:00.800858: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 2023-04-02 04:41:07.394902: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 2023-04-02 04:41:07.395541: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 17 of 10000
# 2023-04-02 04:41:08.625907: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 2023-04-02 04:41:09.008926: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:417] Shuffle buffer filled.
# 2023-04-02 04:41:09.009484: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 1 of 1000
# 2023-04-02 04:41:09.009892: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:417] Shuffle buffer filled.
# 4/4 [==============================] - 15s 778ms/step - loss: 0.7314 - accuracy: 0.8281

# %% [markdown]
# ### Evaluation

# %%
# Scores is just a list containing loss and accuracy value
scores
# Out:
# [0.7313752174377441, 0.828125]

# %% [markdown]
# ### Saving the Model

# %%
import os
model_version=max([int(i) for i in os.listdir("./models") + [0]])+1
model.save(f"./models/{model_version}")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/1/assets
# INFO:tensorflow:Assets written to: ./models/1/assets
